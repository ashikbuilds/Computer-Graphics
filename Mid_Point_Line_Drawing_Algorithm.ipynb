# %%
import matplotlib.pyplot as plt

def plot_circle_points(xc, yc, x, y, points):
    # Using symmetry of circle, plot all eight points
    points.append((xc + x, yc + y))
    points.append((xc - x, yc + y))
    points.append((xc + x, yc - y))
    points.append((xc - x, yc - y))
    points.append((xc + y, yc + x))
    points.append((xc - y, yc + x))
    points.append((xc + y, yc - x))
    points.append((xc - y, yc - x))

def midpoint_circle(xc, yc, r):
    x = 0
    y = r
    p = 1 - r
    points = []

    plot_circle_points(xc, yc, x, y, points)

    while x < y:
        x += 1
        if p < 0:
            p += 2 * x + 1
        else:
            y -= 1
            p += 2 * (x - y) + 1
        plot_circle_points(xc, yc, x, y, points)

    return points

# Example usage
xc, yc, r = 0, 0, 10
circle_points = midpoint_circle(xc, yc, r)

# Plot the circle
x_vals = [p[0] for p in circle_points]
y_vals = [p[1] for p in circle_points]

plt.scatter(x_vals, y_vals)
plt.gca().set_aspect('equal', adjustable='box')
plt.title("Midpoint Circle Drawing Algorithm")
plt.show()

# %%
import matplotlib.pyplot as plt

def plot_circle_points(xc, yc, x, y, points):
    # Using symmetry of circle, plot all eight points
    points.append((xc + x, yc + y))
    points.append((xc - x, yc + y))
    points.append((xc + x, yc - y))
    points.append((xc - x, yc - y))
    points.append((xc + y, yc + x))
    points.append((xc - y, yc + x))
    points.append((xc + y, yc - x))
    points.append((xc - y, yc - x))

def midpoint_circle(xc, yc, r):
    x = 0
    y = r
    p = 1 - r
    points = []

    plot_circle_points(xc, yc, x, y, points)

    while x < y:
        x += 1
        if p < 0:
            p += 2 * x + 1
        else:
            y -= 1
            p += 2 * (x - y) + 1
        plot_circle_points(xc, yc, x, y, points)

    return points

# Example usage
xc, yc, r = 0, 0, 10
circle_points = midpoint_circle(xc, yc, r)

# Sort points to connect them nicely (optional)
circle_points = sorted(circle_points, key=lambda p: (p[0], p[1]))

# Draw lines connecting points
for i in range(len(circle_points)):
    x1, y1 = circle_points[i]
    x2, y2 = circle_points[(i + 1) % len(circle_points)]  # connect last to first
    plt.plot([x1, x2], [y1, y2], 'b')  # 'b' is blue line

plt.gca().set_aspect('equal', adjustable='box')
plt.title("Midpoint Circle with Connected Lines")
plt.show()

# %%
import matplotlib.pyplot as plt

def plot_circle_points(xc, yc, x, y, points):
    # 8-way symmetry
    points.append((xc + x, yc + y))
    points.append((xc - x, yc + y))
    points.append((xc + x, yc - y))
    points.append((xc - x, yc - y))
    points.append((xc + y, yc + x))
    points.append((xc - y, yc + x))
    points.append((xc + y, yc - x))
    points.append((xc - y, yc - x))

def midpoint_circle(xc, yc, r):
    x = 0
    y = r
    p = 1 - r
    points = []

    plot_circle_points(xc, yc, x, y, points)

    while x < y:
        x += 1
        if p < 0:
            p += 2 * x + 1
        else:
            y -= 1
            p += 2 * (x - y) + 1
        plot_circle_points(xc, yc, x, y, points)

    return points

# Example usage
xc, yc, r = 0, 0, 10  # center at (0,0), radius 10
circle_points = midpoint_circle(xc, yc, r)

# Plot circle
x_vals = [p[0] for p in circle_points]
y_vals = [p[1] for p in circle_points]

plt.scatter(x_vals, y_vals, color='blue')
plt.gca().set_aspect('equal', adjustable='box')
plt.title("Midpoint Circle Algorithm with 8-way symmetry")
plt.show()

# %%
# Python3 program for implementing
# Mid-Point Circle Drawing Algorithm

def midPointCircleDraw(x_centre, y_centre, r):
    x = r
    y = 0

    # Printing the initial point the
    # axes after translation
    print("(", x + x_centre, ", ",
               y + y_centre, ")",
               sep = "", end = "")

    # When radius is zero only a single
    # point be printed
    if (r > 0) :

        print("(", x + x_centre, ", ",
                  -y + y_centre, ")",
                  sep = "", end = "")
        print("(", y + x_centre, ", ",
                   x + y_centre, ")",
                   sep = "", end = "")
        print("(", -y + x_centre, ", ",
                    x + y_centre, ")", sep = "")

    # Initialising the value of P
    P = 1 - r

    while x > y:

        y += 1

        # Mid-point inside or on the perimeter
        if P <= 0:
            P = P + 2 * y + 1

        # Mid-point outside the perimeter
        else:
            x -= 1
            P = P + 2 * y - 2 * x + 1

        # All the perimeter points have
        # already been printed
        if (x < y):
            break

        # Printing the generated point its reflection
        # in the other octants after translation
        print("(", x + x_centre, ", ", y + y_centre,
                            ")", sep = "", end = "")
        print("(", -x + x_centre, ", ", y + y_centre,
                             ")", sep = "", end = "")
        print("(", x + x_centre, ", ", -y + y_centre,
                             ")", sep = "", end = "")
        print("(", -x + x_centre, ", ", -y + y_centre,
                                        ")", sep = "")

        # If the generated point on the line x = y then
        # the perimeter points have already been printed
        if x != y:

            print("(", y + x_centre, ", ", x + y_centre,
                                ")", sep = "", end = "")
            print("(", -y + x_centre, ", ", x + y_centre,
                                 ")", sep = "", end = "")
            print("(", y + x_centre, ", ", -x + y_centre,
                                 ")", sep = "", end = "")
            print("(", -y + x_centre, ", ", -x + y_centre,
                                            ")", sep = "")

# Driver Code
if __name__ == '__main__':

    # To draw a circle of radius 3
    # centered at (0, 0)
    midPointCircleDraw(0, 0, 3)


# Contributed by: SHUBHAMSINGH10
# Improved by: siddharthx_07
# Out:
# (3, 0)(3, 0)(0, 3)(0, 3)
# (3, 1)(-3, 1)(3, -1)(-3, -1)
# (1, 3)(-1, 3)(1, -3)(-1, -3)
# (2, 2)(-2, 2)(2, -2)(-2, -2)

# %%
import matplotlib.pyplot as plt

# Midpoint Circle Algorithm
def plot_circle_points(xc, yc, x, y, points):
    points.append((xc + x, yc + y))
    points.append((xc - x, yc + y))
    points.append((xc + x, yc - y))
    points.append((xc - x, yc - y))
    points.append((xc + y, yc + x))
    points.append((xc - y, yc + x))
    points.append((xc + y, yc - x))
    points.append((xc - y, yc - x))

def midpoint_circle(xc, yc, r):
    x = 0
    y = r
    p = 1 - r
    points = []

    plot_circle_points(xc, yc, x, y, points)

    while x < y:
        x += 1
        if p < 0:
            p += 2 * x + 1
        else:
            y -= 1
            p += 2 * (x - y) + 1
        plot_circle_points(xc, yc, x, y, points)

    return points

# Draw circle and connect points
xc, yc, r = 0, 0, 10
circle_points = midpoint_circle(xc, yc, r)

# Sort points by angle for connecting (optional)
import math
circle_points.sort(key=lambda p: math.atan2(p[1]-yc, p[0]-xc))

# Draw lines connecting consecutive points
for i in range(len(circle_points)):
    x1, y1 = circle_points[i]
    x2, y2 = circle_points[(i + 1) % len(circle_points)]
    plt.plot([x1, x2], [y1, y2], 'b')

plt.gca().set_aspect('equal', adjustable='box')
plt.title("Midpoint Circle with Lines (Connected)")
plt.show()
