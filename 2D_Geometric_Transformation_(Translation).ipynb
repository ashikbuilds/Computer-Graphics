# %%
import matplotlib.pyplot as plt


x1 = float(input())
y1 = float(input())
x2 = float(input())
y2 = float(input())
x3 = float(input())
y3 = float(input())

tx = float(input())
ty = float(input())

x1_new = x1 + tx
y1_new = y1 + ty
x2_new = x2 + tx
y2_new = y2 + ty
x3_new = x3 + tx
y3_new = y3 + ty

plt.plot([x1, x2, x3, x1], [y1, y2, y3, y1], 'bo-')
plt.plot([x1_new, x2_new, x3_new, x1_new], [y1_new, y2_new, y3_new, y1_new], 'ro-')
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.grid(True)
plt.axis('equal')
plt.show()
# Out:
# 2
# 3
# 5
# 6
# 8
# 9
# 1
# 4
# /tmp/ipython-input-1995132383.py:25: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
